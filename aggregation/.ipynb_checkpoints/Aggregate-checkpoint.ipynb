# %%
import os
import pickle
import tenseal as ts
import shutil

def aggregate_encrypted_gradients():
    # Load context
    with open("context.ser", "rb") as f:
        context = ts.context_from(f.read())

    base_folder = "received_chunks_bin"
    if not os.path.exists(base_folder):
        print("[SERVER] No received folder found.")
        return

    client_dirs = [d for d in os.listdir(base_folder) if os.path.isdir(os.path.join(base_folder, d))]

    if not client_dirs:
        print("[SERVER] No client gradients to aggregate.")
        return

    # Step 1: Load encrypted chunks per client
    chunk_groups = dict()

    for client_id in client_dirs:
        client_path = os.path.join(base_folder, client_id)
        chunk_files = sorted(
            [f for f in os.listdir(client_path) if f.endswith(".bin")],
            key=lambda x: int(x.split("_")[-1].split(".")[0])
        )

        for fname in chunk_files:
            try:
                idx = int(fname.split("_")[-1].split(".")[0])
                with open(os.path.join(client_path, fname), "rb") as f:
                    payload = pickle.load(f)
                    if isinstance(payload, dict) and "data" in payload:
                        vec = ts.ckks_vector_from(context, payload["data"])
                        chunk_groups.setdefault(idx, []).append(vec)
                        print(f"[SERVER] Loaded chunk: {fname}")
                    else:
                        print(f"[SERVER] Invalid format in {fname}")
            except Exception as e:
                print(f"[SERVER] Failed to load {fname}: {e}")

    if not chunk_groups:
        print("[SERVER] No valid encrypted chunks to aggregate.")
        return

    # Step 2: Aggregate each chunk index across clients
    aggregated_chunks = []

    for idx, vectors in sorted(chunk_groups.items()):
        try:
            enc_sum = vectors[0]
            for vec in vectors[1:]:
                if vec.size() != enc_sum.size():
                    print(f"[SERVER] Skipping mismatched vector at chunk {idx}")
                    continue
                enc_sum += vec
            enc_avg = enc_sum * (1.0 / len(vectors))
            aggregated_chunks.append((idx, enc_avg))
            print(f"[SERVER] Aggregated chunk index {idx}")
        except Exception as e:
            print(f"[SERVER] Failed to aggregate chunk {idx}: {e}")

    # Step 3: Save aggregated encrypted chunks
    output_folder = "aggregated_chunks_bin"
    os.makedirs(output_folder, exist_ok=True)

    for idx, enc_chunk in aggregated_chunks:
        with open(os.path.join(output_folder, f"agg_chunk_{idx}.bin"), "wb") as f:
            pickle.dump(enc_chunk.serialize(), f)

    print(f"[SERVER] Aggregated {len(aggregated_chunks)} encrypted chunks saved in '{output_folder}'")

    # Step 4: Combine for global file
    all_serialized = [chunk.serialize() for _, chunk in aggregated_chunks]
    with open("aggregated_gradient_global_encrypted.pkl", "wb") as f:
        pickle.dump(all_serialized, f)
    print("[SERVER] Final encrypted global gradient ready to be sent to clients.")

    # Cleanup after successful aggregation
    try:
        shutil.rmtree(base_folder)
        print("[SERVER] Cleaned up 'received_chunks_bin' for next round.")
    except Exception as e:
        print(f"[SERVER] Failed to clean up: {e}")

# Entry Point
if __name__ == "__main__":
    aggregate_encrypted_gradients()
# Out:
# [SERVER] Loaded chunk: chunk_0.bin
# [SERVER] Loaded chunk: chunk_1.bin
# [SERVER] Loaded chunk: chunk_0.bin
# [SERVER] Loaded chunk: chunk_1.bin
# [SERVER] Aggregated chunk index 0
# [SERVER] Aggregated chunk index 1
# [SERVER] Aggregated 2 encrypted chunks saved in 'aggregated_chunks_bin'
# [SERVER] Final encrypted global gradient ready to be sent to clients.
# [SERVER] Cleaned up 'received_chunks_bin' for next round.
