# %%
from flask import Flask, request
import ssl, os, pickle
import tenseal as ts

# Load public context only — as a real server would
try:
    with open("context.ser", "rb") as f:
        client_context = ts.context_from(f.read())
except FileNotFoundError:
    print("[SERVER] context.ser file not found. Please copy it from the client.")
    exit(1)

app = Flask(__name__)
UPLOAD_FOLDER = "received_chunks"
os.makedirs(UPLOAD_FOLDER, exist_ok=True)

@app.route('/', methods=['POST'])
def receive_chunk():
    try:
        payload = pickle.loads(request.data)
        chunk_id = payload['chunk_id']
        client_id = payload['client_id']
        data = payload['data']

        # Try to deserialize — this catches tampered ciphertext
        try:
            encrypted = ts.ckks_vector_from(client_context, data)

            # Optional: check that it's a valid gradient size (not garbage)
            if encrypted.size() < 5 or encrypted.size() > 10000:
                print(f"[SERVER] Dropped chunk {chunk_id} — Invalid gradient size: {encrypted.size()}")
                return "Corrupted", 400

        except Exception as e:
            print(f"[SERVER] Dropped chunk {chunk_id} from {client_id} — CKKS validation failed: {e}")
            return "Corrupted", 400

        # Save only if all checks passed
        client_folder = os.path.join("received_chunks_bin", client_id)
        os.makedirs(client_folder, exist_ok=True)

        filename = os.path.join(client_folder, f"chunk_{chunk_id}.bin")
        with open(filename, 'wb') as f:
            pickle.dump({'data': data}, f)

        print(f"[SERVER] Received chunk {chunk_id} from {client_id}")
        return "OK", 200

    except Exception as e:
        print(f"[SERVER] Error receiving chunk: {e}")
        return "Error", 500


def run_server():
    context = ssl.SSLContext(ssl.PROTOCOL_TLS_SERVER)
    context.load_cert_chain(certfile='cert.pem', keyfile='key.pem')

    print("[SERVER] Listening securely on https://127.0.0.1:5055 ...")
    app.run(
        host='127.0.0.1',
        port=5055,
        ssl_context=context,
        threaded=True
    )
if __name__ == "__main__":
    run_server()
# Out:
# [SERVER] Listening securely on https://127.0.0.1:5055 ...
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on https://127.0.0.1:5055
# Press CTRL+C to quit

# %%
import os
print("cert.pem exists:", os.path.exists("cert.pem"))
print("key.pem exists:", os.path.exists("key.pem"))

# %%
file_path = "received_gradients.json"

with open(file_path, "r", encoding="utf-8") as f:
    raw = f.read()

print("Raw length:", len(raw))
print("Preview:\n", raw[:1000])  # First 1000 characters

# %%
with open("fixed_received_gradients.json", "r") as f:
    data = json.load(f)

print(f"Keys: {list(data.keys())}")
print(f"Number of chunks: {len(data['all_encrypted_gradients'])}")
print(f"First 100 chars of chunk 0: {data['all_encrypted_gradients'][0][:100]}")

# %%
import base64
import tenseal as ts

with open("context.ser", "rb") as f:
    context = ts.context_from(f.read())

# Get the first chunk
chunk = data['all_encrypted_gradients'][0]

try:
    decoded = base64.b64decode(chunk)
    vec = ts.ckks_vector_from(context, decoded)
    print("Successfully deserialized chunk 0.")
except Exception as e:
    print("Still not valid CKKS vector:", e)

# %%
import ssl
print("SSL module path:", ssl.__file__)

# %%
import os
print("File exists:", os.path.exists("received_gradients.json"))
