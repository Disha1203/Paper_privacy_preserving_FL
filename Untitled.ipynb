# %%
import sys
sys.path.insert(0, "/Users/ravi/Desktop/Paper/hybrid-privacy-fl-healthcare")

from config import *
from utils.seed import fix_all_seeds
from utils.logger import log_result

fix_all_seeds()
print(f"Experiment: {EXPERIMENT_NAME}")
print(f"DP: {DP_ENABLED}, HE: {HE_ENABLED}")
print(f"Seed: {SEED}")
print("Foundation files working correctly")
# Out:
# [SEED] All seeds fixed to 42
# Experiment: fl_anon_dp_he
# DP: True, HE: True
# Seed: 42
# Foundation files working correctly
